# %%
import requests
from pprint import pprint
from requests.structures import CaseInsensitiveDict

# %%
url= "https://api.estadisticasbcra.com/usd" #cotizacion del usd blue
headers= CaseInsensitiveDict()
headers["Accept"]="application/json"
headers["Authorization"]="BEARER eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE2OTA5Mzk5NzEsInR5cGUiOiJleHRlcm5hbCIsInVzZXIiOiJlc3RlZmFuaWFzdXNhbmpAZ21haWwuY29tIn0.GEKEzKkO-rBZj8t-Q3HuPZWDQjZvLrm8NfI9-5QT7tJgL6KpfDU60bocJX_84lHNq9cjqRGS5DHaI9eoa9RDIw"
response= requests.get(url, headers=headers)
pprint(response.json())
# Out:
# [{'d': '2000-05-24', 'v': 1.0005},
#  {'d': '2000-05-25', 'v': 1.0005},
#  {'d': '2000-05-26', 'v': 1.0004},
#  {'d': '2000-05-29', 'v': 1.0007},
#  {'d': '2000-05-30', 'v': 1.0009},
#  {'d': '2000-05-31', 'v': 1.001},
#  {'d': '2000-06-01', 'v': 1.0007},
#  {'d': '2000-06-02', 'v': 1.0011},
#  {'d': '2000-06-05', 'v': 1.0011},
#  {'d': '2000-06-06', 'v': 1.001},
#  {'d': '2000-06-07', 'v': 1},
#  {'d': '2000-06-08', 'v': 0.9998},
#  {'d': '2000-06-12', 'v': 0.9998},
#  {'d': '2000-06-13', 'v': 0.9996},
#  {'d': '2000-06-14', 'v': 0.9999},
#  {'d': '2000-06-15', 'v': 0.9988},
#  {'d': '2000-06-16', 'v': 0.9988},
#  {'d': '2000-06-19', 'v': 0.9988},
#  {'d': '2000-06-20', 'v': 0.9994},
#  {'d': '2000-06-21', 'v': 0.9996},
#  {'d': '2000-06-22', 'v': 0.9991},
#  {'d': '2000-06-23', 'v': 0.9985},
#  {'d': '2000-06-26', 'v': 0.999},
#  {'d': '2000-06-27', 'v': 0.9994},
#  {'d': '2000-06-28', 'v': 0.999},
#  {'d': '2000-06-29', 'v': 0.9987},
#  {'d': '2000-06-30', 'v': 0.9985},
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mp

# %%
import json

# %%
dolarblue = json.dumps(response.json())

# %%
df=pd.read_json(dolarblue)

# %%
df
# Out:
#                d         v
# 0     2000-05-24    1.0005
# 1     2000-05-25    1.0005
# 2     2000-05-26    1.0004
# 3     2000-05-29    1.0007
# 4     2000-05-30    1.0009
# ...          ...       ...
# 5562  2022-07-29  296.0000
# 5563  2022-08-01  282.0000
# 5564  2022-08-02  291.0000
# 5565  2022-08-03  298.0000
# 5566  2022-08-04  291.0000
#
# [5567 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5567 entries, 0 to 5566
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   d       5567 non-null   object
#  1   v       5567 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 87.1+ KB

# %%
df.describe()
# Out:
#                  v
# count  5567.000000
# mean     27.032016
# std      52.942123
# min       0.996500
# 25%       3.092500
# 50%       4.157500
# 75%      15.910000
# max     338.000000

# %%
df.shape
# Out:
# (5567, 2)

# %%
#"https://api.estadisticasbcra.com/usd" #cotizacion del usd
url1="https://api.estadisticasbcra.com/usd_of" #cotiz oficial
headers= CaseInsensitiveDict()
headers["Accept"]="application/json"
headers["Authorization"]="BEARER eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE2OTA5Mzk5NzEsInR5cGUiOiJleHRlcm5hbCIsInVzZXIiOiJlc3RlZmFuaWFzdXNhbmpAZ21haWwuY29tIn0.GEKEzKkO-rBZj8t-Q3HuPZWDQjZvLrm8NfI9-5QT7tJgL6KpfDU60bocJX_84lHNq9cjqRGS5DHaI9eoa9RDIw"
response1= requests.get(url1, headers=headers)
pprint(response1.json())
# Out:
# [{'d': '2002-03-04', 'v': 2.01},
#  {'d': '2002-03-05', 'v': 1.99},
#  {'d': '2002-03-06', 'v': 2.05},
#  {'d': '2002-03-07', 'v': 2.14},
#  {'d': '2002-03-08', 'v': 2.2},
#  {'d': '2002-03-11', 'v': 2.25},
#  {'d': '2002-03-12', 'v': 2.37},
#  {'d': '2002-03-13', 'v': 2.33},
#  {'d': '2002-03-14', 'v': 2.37},
#  {'d': '2002-03-15', 'v': 2.34},
#  {'d': '2002-03-18', 'v': 2.32},
#  {'d': '2002-03-19', 'v': 2.38},
#  {'d': '2002-03-20', 'v': 2.43},
#  {'d': '2002-03-21', 'v': 2.39},
#  {'d': '2002-03-22', 'v': 2.57},
#  {'d': '2002-03-25', 'v': 3.21},
#  {'d': '2002-03-26', 'v': 2.99},
#  {'d': '2002-03-27', 'v': 2.85},
#  {'d': '2002-04-02', 'v': 2.89},
#  {'d': '2002-04-03', 'v': 2.9},
#  {'d': '2002-04-04', 'v': 2.8},
#  {'d': '2002-04-05', 'v': 2.67},
#  {'d': '2002-04-08', 'v': 2.7},
#  {'d': '2002-04-09', 'v': 2.75},
#  {'d': '2002-04-10', 'v': 2.77},
#  {'d': '2002-04-11', 'v': 2.79},
#  {'d': '2002-04-12', 'v': 2.86},
#  {'d': '2002-04-15', 'v': 2.92},
# ...

# %%
dolarof = json.dumps(response1.json())

# %%
df1=pd.read_json(dolarof)

# %%
df1
# Out:
#                d       v
# 0     2002-03-04    2.01
# 1     2002-03-05    1.99
# 2     2002-03-06    2.05
# 3     2002-03-07    2.14
# 4     2002-03-08    2.20
# ...          ...     ...
# 5011  2022-07-29  131.23
# 5012  2022-08-01  131.94
# 5013  2022-08-02  132.18
# 5014  2022-08-03  132.41
# 5015  2022-08-04  132.64
#
# [5016 rows x 2 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5016 entries, 0 to 5015
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   d       5016 non-null   object
#  1   v       5016 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 78.5+ KB

# %%
df1.describe()
# Out:
#                  v
# count  5016.000000
# mean     19.512646
# std      29.726474
# min       1.990000
# 25%       3.140000
# 50%       4.390000
# 75%      16.042500
# max     132.640000

# %%
df1.shape
# Out:
# (5016, 2)

# %%
comparacion= pd.merge(df,df1, on= 'd', how= 'left')

# %%
comparacion
# Out:
#                d       v_x     v_y
# 0     2000-05-24    1.0005     NaN
# 1     2000-05-25    1.0005     NaN
# 2     2000-05-26    1.0004     NaN
# 3     2000-05-29    1.0007     NaN
# 4     2000-05-30    1.0009     NaN
# ...          ...       ...     ...
# 5562  2022-07-29  296.0000  131.23
# 5563  2022-08-01  282.0000  131.94
# 5564  2022-08-02  291.0000  132.18
# 5565  2022-08-03  298.0000  132.41
# 5566  2022-08-04  291.0000  132.64
#
# [5567 rows x 3 columns]

# %%
comparacion.dropna(inplace=True)

# %%
comparacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5010 entries, 442 to 5566
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   d       5010 non-null   object
#  1   v_x     5010 non-null   float64
#  2   v_y     5010 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 156.6+ KB

# %%
from datetime  import datetime
month = []
year = []
for i in comparacion['d']:
    date = datetime.strptime(i, '%Y-%m-%d')
    month.append(date.strftime('%m'))
    year.append(date.strftime('%Y'))
    
comparacion['Mes']= month
comparacion['Año']= year

# %%
for i in comparacion['d']:
    date = datetime.strptime(i, '%Y-%m-%d')

# %%
comparacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5010 entries, 442 to 5566
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   d       5010 non-null   object
#  1   v_x     5010 non-null   float64
#  2   v_y     5010 non-null   float64
#  3   Mes     5010 non-null   object
#  4   Año     5010 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 234.8+ KB

# %%
comparacion.rename(columns= {'d': 'Fecha', 'v_x': 'DolarBlue', 'v_y': 'DolarOficial'}, inplace=True)

# %%
comparacion
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 442   2002-03-04       2.12          2.01  03  2002
# 443   2002-03-05       2.12          1.99  03  2002
# 444   2002-03-06       2.14          2.05  03  2002
# 445   2002-03-07       2.22          2.14  03  2002
# 446   2002-03-08       2.27          2.20  03  2002
# ...          ...        ...           ...  ..   ...
# 5562  2022-07-29     296.00        131.23  07  2022
# 5563  2022-08-01     282.00        131.94  08  2022
# 5564  2022-08-02     291.00        132.18  08  2022
# 5565  2022-08-03     298.00        132.41  08  2022
# 5566  2022-08-04     291.00        132.64  08  2022
#
# [5010 rows x 5 columns]

# %%
ultimo_año = comparacion.iloc[-246:] 
ultimo_año.head(246)
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 5321  2021-08-04      180.5         96.84  08  2021
# 5322  2021-08-05      180.5         96.88  08  2021
# 5323  2021-08-06      178.5         96.91  08  2021
# 5324  2021-08-09      179.0         97.00  08  2021
# 5325  2021-08-10      178.0         97.03  08  2021
# ...          ...        ...           ...  ..   ...
# 5562  2022-07-29      296.0        131.23  07  2022
# 5563  2022-08-01      282.0        131.94  08  2022
# 5564  2022-08-02      291.0        132.18  08  2022
# 5565  2022-08-03      298.0        132.41  08  2022
# 5566  2022-08-04      291.0        132.64  08  2022
#
# [246 rows x 5 columns]

# %%
ultimo_año
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 5321  2021-08-04      180.5         96.84  08  2021
# 5322  2021-08-05      180.5         96.88  08  2021
# 5323  2021-08-06      178.5         96.91  08  2021
# 5324  2021-08-09      179.0         97.00  08  2021
# 5325  2021-08-10      178.0         97.03  08  2021
# ...          ...        ...           ...  ..   ...
# 5562  2022-07-29      296.0        131.23  07  2022
# 5563  2022-08-01      282.0        131.94  08  2022
# 5564  2022-08-02      291.0        132.18  08  2022
# 5565  2022-08-03      298.0        132.41  08  2022
# 5566  2022-08-04      291.0        132.64  08  2022
#
# [246 rows x 5 columns]

# %%
from math import log

# %%
pct_change =((ultimo_año["DolarBlue"]) / (ultimo_año["DolarBlue"].shift(+1)))

# %%
ultimo_año['gap']=np.log(ultimo_año['DolarBlue']/ultimo_año['DolarBlue'].shift(1)) #los gaps se dan en las aperturas y los cierres
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\2462198032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimo_año['gap']=np.log(ultimo_año['DolarBlue']/ultimo_año['DolarBlue'].shift(1)) #los gaps se dan en las aperturas y los cierres

# %%
ultimo_año['variacion']=((ultimo_año['DolarBlue']/ultimo_año['DolarOficial'])-1)*100
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\696353429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimo_año['variacion']=((ultimo_año['DolarBlue']/ultimo_año['DolarOficial'])-1)*100

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,8))
x=ultimo_año['Fecha']
y=ultimo_año['variacion']
plt.plot(x, y)

# %%
brecha_max= ultimo_año['variacion'].idxmax() #para sacar el dia con mayor variacion

ultimo_año.loc[brecha_max]
# Out:
# Fecha           2022-07-22
# DolarBlue            338.0
# DolarOficial        129.76
# Mes                     07
# Año                   2022
# gap               0.002963
# variacion       160.480888
# Name: 5557, dtype: object

# %%
ultimo_año
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año       gap   variacion
# 5321  2021-08-04      180.5         96.84  08  2021       NaN   86.389922
# 5322  2021-08-05      180.5         96.88  08  2021  0.000000   86.312964
# 5323  2021-08-06      178.5         96.91  08  2021 -0.011142   84.191518
# 5324  2021-08-09      179.0         97.00  08  2021  0.002797   84.536082
# 5325  2021-08-10      178.0         97.03  08  2021 -0.005602   83.448418
# ...          ...        ...           ...  ..   ...       ...         ...
# 5562  2022-07-29      296.0        131.23  07  2022 -0.059034  125.558180
# 5563  2022-08-01      282.0        131.94  08  2022 -0.048452  113.733515
# 5564  2022-08-02      291.0        132.18  08  2022  0.031416  120.154335
# 5565  2022-08-03      298.0        132.41  08  2022  0.023770  125.058530
# 5566  2022-08-04      291.0        132.64  08  2022 -0.023770  119.390832
#
# [246 rows x 7 columns]

# %%
variacion=((ultimo_año['DolarBlue']/ultimo_año['DolarOficial'])-1)*100

# %%
ultimo_año['volatilidad']= ultimo_año['variacion'].rolling(40).std()*100*(40**0.5)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\3108086954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimo_año['volatilidad']= ultimo_año['variacion'].rolling(40).std()*100*(40**0.5)

# %%
plt.figure(figsize = (10,8))
x1=ultimo_año['Fecha']
y1=ultimo_año['volatilidad']
plt.plot(x1, y1)

# %%
ultimo_año.sort_values(by='volatilidad', ascending=False).head(5) #top 5 mayor volatilidad
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año       gap   variacion  \
# 5561  2022-07-28      314.0        131.13  07  2022 -0.037504  139.457027
# 5562  2022-07-29      296.0        131.23  07  2022 -0.059034  125.558180
# 5560  2022-07-27      326.0        130.89  07  2022  0.009245  149.064100
# 5563  2022-08-01      282.0        131.94  08  2022 -0.048452  113.733515
# 5559  2022-07-26      323.0        130.62  07  2022  0.003101  147.282193
#
#        volatilidad
# 5561  18314.063982
# 5562  18181.778196
# 5560  18150.647710
# 5563  17901.044438
# 5559  17656.526486

# %%
ultimo_año['SemanaAño'] =pd.PeriodIndex(ultimo_año['Fecha'], freq='W')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\1475355102.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimo_año['SemanaAño'] =pd.PeriodIndex(ultimo_año['Fecha'], freq='W')

# %%
ultimo_año
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año       gap   variacion  \
# 5321  2021-08-04      180.5         96.84  08  2021       NaN   86.389922
# 5322  2021-08-05      180.5         96.88  08  2021  0.000000   86.312964
# 5323  2021-08-06      178.5         96.91  08  2021 -0.011142   84.191518
# 5324  2021-08-09      179.0         97.00  08  2021  0.002797   84.536082
# 5325  2021-08-10      178.0         97.03  08  2021 -0.005602   83.448418
# ...          ...        ...           ...  ..   ...       ...         ...
# 5562  2022-07-29      296.0        131.23  07  2022 -0.059034  125.558180
# 5563  2022-08-01      282.0        131.94  08  2022 -0.048452  113.733515
# 5564  2022-08-02      291.0        132.18  08  2022  0.031416  120.154335
# 5565  2022-08-03      298.0        132.41  08  2022  0.023770  125.058530
# 5566  2022-08-04      291.0        132.64  08  2022 -0.023770  119.390832
#
#        volatilidad              SemanaAño
# ...

# %%
SemanaVariacionBrecha= ultimo_año.groupby("SemanaAño") ['variacion'].mean()#agrupo por semana y calculo el promedio de cada semana para comparar con las demas 
SemanaVariacionBrecha
# Out:
# SemanaAño
# 2021-08-02/2021-08-08     85.631468
# 2021-08-09/2021-08-15     84.536084
# 2021-08-16/2021-08-22     87.222285
# 2021-08-23/2021-08-29     86.480792
# 2021-08-30/2021-09-05     85.601909
# 2021-09-06/2021-09-12     88.528528
# 2021-09-13/2021-09-19     87.140527
# 2021-09-20/2021-09-26     87.591164
# 2021-09-27/2021-10-03     88.925972
# 2021-10-04/2021-10-10     87.029316
# 2021-10-11/2021-10-17     87.099533
# 2021-10-18/2021-10-24     90.556317
# 2021-10-25/2021-10-31     97.268348
# 2021-11-01/2021-11-07     98.405923
# 2021-11-08/2021-11-14    101.716935
# 2021-11-15/2021-11-21    100.063468
# 2021-11-22/2021-11-28     99.548027
# 2021-11-29/2021-12-05     98.776881
# 2021-12-06/2021-12-12     94.564875
# 2021-12-13/2021-12-19     94.228919
# 2021-12-20/2021-12-26     96.473070
# 2021-12-27/2022-01-02    101.274988
# 2022-01-03/2022-01-09    100.953299
# 2022-01-10/2022-01-16    101.129718
# 2022-01-17/2022-01-23    104.545030
# 2022-01-24/2022-01-30    109.115049
# ...

# %%
plt.figure(figsize = (10,8))
ultimo_año.groupby("SemanaAño") ['variacion'].mean().plot(kind='bar',legend='Reverse')
plt.show()

# %%
#Busco la posicion del valor max de SemanaVariacionBrecha
SemanaVariacionBrecha.idxmax()
# Out:
# Period('2022-07-18/2022-07-24', 'W-SUN')

# %%
#Me fijo que valor es
SemanaVariacionBrecha.max()
# Out:
# 144.86845339295692

# %%
periodoIndex =pd.PeriodIndex(ultimo_año['Fecha'], freq='d') #creo la formula para calcular los días de la semana

# %%
ultimo_año['DiaSemana']= periodoIndex.weekday #con la formula anterior agrego esta columna que contiene los dias de la semana
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\617132612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimo_año['DiaSemana']= periodoIndex.weekday #con la formula anterior agrego esta columna que contiene los dias de la semana

# %%
ultimo_año # El dia de la semana Lunes=0, Martes=1, Miercoles=2, Jueves=3, Viernes=4
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año       gap   variacion  \
# 5321  2021-08-04      180.5         96.84  08  2021       NaN   86.389922
# 5322  2021-08-05      180.5         96.88  08  2021  0.000000   86.312964
# 5323  2021-08-06      178.5         96.91  08  2021 -0.011142   84.191518
# 5324  2021-08-09      179.0         97.00  08  2021  0.002797   84.536082
# 5325  2021-08-10      178.0         97.03  08  2021 -0.005602   83.448418
# ...          ...        ...           ...  ..   ...       ...         ...
# 5562  2022-07-29      296.0        131.23  07  2022 -0.059034  125.558180
# 5563  2022-08-01      282.0        131.94  08  2022 -0.048452  113.733515
# 5564  2022-08-02      291.0        132.18  08  2022  0.031416  120.154335
# 5565  2022-08-03      298.0        132.41  08  2022  0.023770  125.058530
# 5566  2022-08-04      291.0        132.64  08  2022 -0.023770  119.390832
#
#        volatilidad              SemanaAño  DiaSemana
# ...

# %% [markdown]
# Renombre los datos de la columna DiaSemana para que queden con el nombre de la semana correspondiente y no ordenados por un ordinal

# %%
ultimo_año.replace({'DiaSemana': 0}, {'DiaSemana': 'Lunes'}, regex=True, inplace=True)
ultimo_año.replace({'DiaSemana': 1}, {'DiaSemana': 'Martes'}, regex=True,inplace=True)
ultimo_año.replace({'DiaSemana': 2}, {'DiaSemana': 'Miercoles'}, regex=True,inplace=True)
ultimo_año.replace({'DiaSemana': 3}, {'DiaSemana': 'Jueves'}, regex=True,inplace=True)
ultimo_año.replace({'DiaSemana': 4}, {'DiaSemana': 'Viernes'}, regex=True,inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\1853738565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimo_año.replace({'DiaSemana': 0}, {'DiaSemana': 'Lunes'}, regex=True, inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\1853738565.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimo_año.replace({'DiaSemana': 1}, {'DiaSemana': 'Martes'}, regex=True,inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\1853738565.py:3: SettingWithCopyWarning:
# ...

# %%
ultimo_año
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año       gap   variacion  \
# 5321  2021-08-04      180.5         96.84  08  2021       NaN   86.389922
# 5322  2021-08-05      180.5         96.88  08  2021  0.000000   86.312964
# 5323  2021-08-06      178.5         96.91  08  2021 -0.011142   84.191518
# 5324  2021-08-09      179.0         97.00  08  2021  0.002797   84.536082
# 5325  2021-08-10      178.0         97.03  08  2021 -0.005602   83.448418
# ...          ...        ...           ...  ..   ...       ...         ...
# 5562  2022-07-29      296.0        131.23  07  2022 -0.059034  125.558180
# 5563  2022-08-01      282.0        131.94  08  2022 -0.048452  113.733515
# 5564  2022-08-02      291.0        132.18  08  2022  0.031416  120.154335
# 5565  2022-08-03      298.0        132.41  08  2022  0.023770  125.058530
# 5566  2022-08-04      291.0        132.64  08  2022 -0.023770  119.390832
#
#        volatilidad              SemanaAño  DiaSemana
# ...

# %%
DiaVariacionBrecha= ultimo_año.groupby("DiaSemana") ['variacion'].mean()
DiaVariacionBrecha
# Out:
# DiaSemana
# Jueves       93.472635
# Lunes        91.474820
# Martes       92.120418
# Miercoles    93.595157
# Viernes      92.570413
# Name: variacion, dtype: float64

# %%
plt.figure(figsize = (10,8))
ultimo_año.groupby("DiaSemana") ['variacion'].mean().plot(kind='pie', autopct="%0.1f %%" )
plt.show()

# %%
DiaVariacionBrecha.idxmax()
# Out:
# 'Miercoles'

# %% [markdown]
# # # **Creo un nuevo DataFrame que contenga los ultimos 10 años para poder hacer un analisis socio-politico**

# %%
ultimos_10años = comparacion.iloc[-2430:]

# %%
ultimos_10años
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 3128  2012-08-03       6.20          4.59  08  2012
# 3129  2012-08-06       6.21          4.59  08  2012
# 3130  2012-08-07       6.26          4.59  08  2012
# 3131  2012-08-08       6.26          4.60  08  2012
# 3132  2012-08-09       6.26          4.60  08  2012
# ...          ...        ...           ...  ..   ...
# 5562  2022-07-29     296.00        131.23  07  2022
# 5563  2022-08-01     282.00        131.94  08  2022
# 5564  2022-08-02     291.00        132.18  08  2022
# 5565  2022-08-03     298.00        132.41  08  2022
# 5566  2022-08-04     291.00        132.64  08  2022
#
# [2430 rows x 5 columns]

# %%
ultimos_10años.groupby("Año") ['DolarBlue'].mean().plot(kind='bar',legend='Reverse')
# Out:
# <AxesSubplot:xlabel='Año'>

# %%
plt.figure(figsize = (20,20))
ultimos_10años.groupby(by=['Año','Mes']).mean().plot(kind='bar',legend='Reverse')
# Out:
# <AxesSubplot:xlabel='Año,Mes'>

# %%
plt.figure(figsize = (20,20))
ultimos_10años.groupby(by=['Año','Mes']) ['DolarBlue'].mean().plot(kind='bar',legend='Reverse')
# Out:
# <AxesSubplot:xlabel='Año,Mes'>

# %%
plt.figure(figsize = (20,20))
ultimos_10años.groupby(by=['Año','Mes']) ['DolarOficial'].mean().plot(kind='bar',legend='Reverse', color="r")
# Out:
# <AxesSubplot:xlabel='Año,Mes'>

# %% [markdown]
# Se evidencia que desde 2019 hay un crecimiento de ambos dolares para poder ver con mayor precision porque esto ocurre haré un grafico año por año para poder inferir,sumando noticias locales que causo esta suba

# %%
en_2019= ultimos_10años[ultimos_10años.Año.isin(['2019'])]
en_2019
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 4691  2019-01-02      40.50         37.93  01  2019
# 4692  2019-01-03      40.25         37.55  01  2019
# 4693  2019-01-04      40.00         37.39  01  2019
# 4694  2019-01-07      39.50         37.36  01  2019
# 4695  2019-01-08      39.25         37.37  01  2019
# ...          ...        ...           ...  ..   ...
# 4930  2019-12-20      75.00         59.82  12  2019
# 4931  2019-12-23      76.75         59.86  12  2019
# 4932  2019-12-26      80.00         59.92  12  2019
# 4933  2019-12-27      78.50         59.89  12  2019
# 4934  2019-12-30      78.50         59.90  12  2019
#
# [243 rows x 5 columns]

# %%
en_2019.groupby(by=['Mes']).mean().plot(kind='bar',legend='Reverse')
# Out:
# <AxesSubplot:xlabel='Mes'>

# %% [markdown]
# En la grafica anterior podemos observar que el 2019 se dispara la brecha en el mes 08, y luego se mantiene en alza, para poder hace un analisis mas certero voy a graficar solo agosto de este año para delucidar la causa del aumento de la brecha cambiaraia

# %%
en_2019_08= en_2019[en_2019.Mes.isin(['08'])]
en_2019_08
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 4832  2019-08-01      45.43         44.32  08  2019
# 4833  2019-08-02      45.90         44.70  08  2019
# 4834  2019-08-05      46.60         45.44  08  2019
# 4835  2019-08-06      46.40         45.35  08  2019
# 4836  2019-08-07      46.50         45.69  08  2019
# 4837  2019-08-08      46.72         45.41  08  2019
# 4838  2019-08-09      46.90         45.40  08  2019
# 4839  2019-08-12      57.00         55.75  08  2019
# 4840  2019-08-13      57.00         56.32  08  2019
# 4841  2019-08-14      62.00         58.84  08  2019
# 4842  2019-08-15      59.00         56.63  08  2019
# 4843  2019-08-16      59.00         56.44  08  2019
# 4844  2019-08-20      58.00         55.36  08  2019
# 4845  2019-08-21      58.50         54.92  08  2019
# 4846  2019-08-22      58.00         55.03  08  2019
# 4847  2019-08-23      58.00         55.27  08  2019
# 4848  2019-08-26      57.50         55.34  08  2019
# ...

# %%
en_2019_08.groupby(by=['Fecha']).mean().plot(kind='bar',legend='Reverse')
# Out:
# <AxesSubplot:xlabel='Fecha'>

# %% [markdown]
# Se puede observar en esta grafica que el aumento en la brecha se produjo, luego de las elecciones parlamentarias, llevadas a cabo el día anterior (domingo 11/08/2019)

# %%
en_2020=ultimos_10años[ultimos_10años.Año.isin(['2020'])]
en_2020
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 4935  2020-01-02      77.00         59.85  01  2020
# 4936  2020-01-03      77.00         59.83  01  2020
# 4937  2020-01-06      77.25         59.82  01  2020
# 4938  2020-01-07      76.25         59.82  01  2020
# 4939  2020-01-08      76.50         59.82  01  2020
# ...          ...        ...           ...  ..   ...
# 5173  2020-12-22     151.00         83.25  12  2020
# 5174  2020-12-23     159.00         83.36  12  2020
# 5175  2020-12-28     164.00         83.91  12  2020
# 5176  2020-12-29     165.00         84.03  12  2020
# 5177  2020-12-30     166.00         84.15  12  2020
#
# [240 rows x 5 columns]

# %%
en_2020.groupby(by=['Mes']).mean().plot(kind='bar',legend='Reverse')
# Out:
# <AxesSubplot:xlabel='Mes'>

# %% [markdown]
# En este grafico podemos observar que hay dos grandes saltos uno se produce durante el mes de mayo y el otro durante octubre, procederé a realizar los graficos de los meses correspondientes a fin de poder deducir la fecha y la causa de esto

# %%
en_2020_05= en_2020[en_2020.Mes.isin(['05'])]
en_2020_05
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 5014  2020-05-04      120.0         66.93  05  2020
# 5015  2020-05-05      120.0         67.01  05  2020
# 5016  2020-05-06      122.0         67.10  05  2020
# 5017  2020-05-07      122.0         67.19  05  2020
# 5018  2020-05-08      122.0         67.28  05  2020
# 5019  2020-05-11      124.5         67.37  05  2020
# 5020  2020-05-12      127.0         67.46  05  2020
# 5021  2020-05-13      133.0         67.55  05  2020
# 5022  2020-05-14      138.0         67.64  05  2020
# 5023  2020-05-15      138.0         67.73  05  2020
# 5024  2020-05-18      128.0         67.82  05  2020
# 5025  2020-05-19      124.0         67.91  05  2020
# 5026  2020-05-20      124.0         68.00  05  2020
# 5027  2020-05-21      125.0         68.09  05  2020
# 5028  2020-05-22      126.0         68.18  05  2020
# 5029  2020-05-26      129.0         68.27  05  2020
# 5030  2020-05-27      127.0         68.36  05  2020
# ...

# %%
en_2020_05.groupby(by=['Fecha']).mean().plot(kind='bar')
plt.legend(loc='upper left')

# %% [markdown]
# En base a lo encontrado en diversos articulos periodisticos, el dia 14 de mayo de 2020, fue el dia con mas muertos por la pandemia y tambien a causa de la cuarentena estricta(Infobae), tambien durante ese dia se dio a conocer la inflacion de Abril/2020 informa que fue de 1.5(El Pais) y que durante el primer trimestre del corriente año se imprimieron mas de 600.000 millones de pesos. Esto ultimo en un principio podria tener relacion con la depreciacion del peso frente al dolar.

# %%
en_2020_10= en_2020[en_2020.Mes.isin(['10'])]
en_2020_10
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 5119  2020-10-01      147.0         76.25  10  2020
# 5120  2020-10-02      150.0         76.95  10  2020
# 5121  2020-10-05      150.0         77.05  10  2020
# 5122  2020-10-06      152.0         77.08  10  2020
# 5123  2020-10-07      155.0         77.10  10  2020
# 5124  2020-10-08      158.0         77.10  10  2020
# 5125  2020-10-09      167.0         77.11  10  2020
# 5126  2020-10-13      166.0         77.40  10  2020
# 5127  2020-10-14      167.0         77.42  10  2020
# 5128  2020-10-15      171.0         77.46  10  2020
# 5129  2020-10-16      178.0         77.53  10  2020
# 5130  2020-10-19      181.0         77.58  10  2020
# 5131  2020-10-20      180.0         77.66  10  2020
# 5132  2020-10-21      183.0         77.71  10  2020
# 5133  2020-10-22      190.0         78.05  10  2020
# 5134  2020-10-23      195.0         78.09  10  2020
# 5135  2020-10-26      190.0         78.21  10  2020
# ...

# %%
en_2020_10.groupby(by=['Fecha']).mean().plot(kind='bar')
plt.legend(loc='upper left')

# %% [markdown]
# Podemos observar que el dia donde la brecha cambiaria fue mayor corresponde al 23/10/2020, dia en que se anuncia que la tasa de letalidad por covid se duplico(Infobae)

# %%
en_2021= ultimos_10años[ultimos_10años.Año.isin(['2021'])]
en_2021
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 5178  2021-01-04      165.0         84.70  01  2021
# 5179  2021-01-05      160.0         84.80  01  2021
# 5180  2021-01-06      160.0         84.90  01  2021
# 5181  2021-01-07      162.0         85.00  01  2021
# 5182  2021-01-08      161.0         85.11  01  2021
# ...          ...        ...           ...  ..   ...
# 5417  2021-12-23      204.0        102.33  12  2021
# 5418  2021-12-27      203.5        102.57  12  2021
# 5419  2021-12-28      206.0        102.62  12  2021
# 5420  2021-12-29      209.0        102.69  12  2021
# 5421  2021-12-30      208.0        102.75  12  2021
#
# [243 rows x 5 columns]

# %%
en_2021.groupby(by=['Mes']).mean().plot(kind='bar',legend='Reverse')
# Out:
# <AxesSubplot:xlabel='Mes'>

# %% [markdown]
# En este grafico podemos observar que los mayores saltos en la brecha cambiaria se dan durante el mes 07 y el 11. Hare sus respectivos graficos para ver si puedo hallar la causa de ello.

# %%
en_2021_07= en_2021[en_2021.Mes.isin(['07'])]
en_2021_07.groupby(by=['Fecha']).mean().plot(kind='bar')
plt.legend(loc='upper left')

# %% [markdown]
# Podemos observar que el dia de mayor fluctacion en la brecha, aqui es el 22/7/2021, dia en que consecuentemente el gobierno NorteAmericano lanza un informe adviertiendo a los inversionistas que desaconsejan invertir en la Argetina, puesto que su economia es "Intervencionista" y "impredecible"(Cronista)

# %%
en_2021_11= en_2021[en_2021.Mes.isin(['11'])]
en_2021_11.groupby(by=['Fecha']).mean().plot(kind='bar')
plt.legend(loc='upper right')

# %% [markdown]
# Aqui vemos que hay un brecha el dia 11 y 12 que son previas a las elecciones parlamentarias que por sondeos se sabia que el oficialismo perdia

# %%
en_2022=ultimos_10años[ultimos_10años.Año.isin(['2022'])]
en_2022
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 5422  2022-01-03      206.0        103.04  01  2022
# 5423  2022-01-04      206.5        103.08  01  2022
# 5424  2022-01-05      207.5        103.15  01  2022
# 5425  2022-01-06      208.5        103.23  01  2022
# 5426  2022-01-07      208.0        103.29  01  2022
# ...          ...        ...           ...  ..   ...
# 5562  2022-07-29      296.0        131.23  07  2022
# 5563  2022-08-01      282.0        131.94  08  2022
# 5564  2022-08-02      291.0        132.18  08  2022
# 5565  2022-08-03      298.0        132.41  08  2022
# 5566  2022-08-04      291.0        132.64  08  2022
#
# [145 rows x 5 columns]

# %%
en_2022.groupby(by=['Mes']).mean().plot(kind='bar',legend='Reverse')
# Out:
# <AxesSubplot:xlabel='Mes'>

# %% [markdown]
# Podemos observar que a partir del mes de julio la brecha de dispara, haré un grafico de este mes para poder ver que dia exacto influyo en esto

# %%
en_2022_07= en_2022[en_2022.Mes.isin(['07'])]
en_2022_07.groupby(by=['Fecha']).mean().plot(kind='bar')
plt.legend(loc='upper right')

# %% [markdown]
# Podemos observar como a partir del 04/07, fecha en que aceptada la renuncia de del ministro de Economia y es designada la Dra. Batakis en su lugar, la brecha se dispara. Luego se observa que el dia 21/07/2022 tambien se vuelve disparar, y esto coincide conel anuncio de un paquetes de medidas economicas.

# %% [markdown]
# # # # **Regresion lineal con ambos dolares**

# %%
df= pd.DataFrame(ultimo_año)

# %%
import numpy as np
import pandas as pd
import math as math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ultimos_10años['variacion']=((ultimos_10años['DolarBlue']/ultimos_10años['DolarOficial'])-1)*100
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\2020423667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_10años['variacion']=((ultimos_10años['DolarBlue']/ultimos_10años['DolarOficial'])-1)*100

# %%
ultimos_10años['volatilidad']= ultimos_10años['variacion'].rolling(40).std()*100*(40**0.5)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\700749461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_10años['volatilidad']= ultimos_10años['variacion'].rolling(40).std()*100*(40**0.5)

# %%
sns.scatterplot(x="Año", y="variacion", data=ultimos_10años)
# Out:
# <AxesSubplot:xlabel='Año', ylabel='variacion'>

# %%
sns.lineplot(x="Año", y="volatilidad", data=ultimos_10años)
# Out:
# <AxesSubplot:xlabel='Año', ylabel='volatilidad'>

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)

# %%
ultimos_10años['Fecha'] = pd.to_datetime(ultimos_10años['Fecha'], format="%Y/%m/%d")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\81319581.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_10años['Fecha'] = pd.to_datetime(ultimos_10años['Fecha'], format="%Y/%m/%d")

# %%
import datetime as dt
ultimos_10años['Fecha']=ultimos_10años['Fecha'].map(dt.datetime.toordinal)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\4228129974.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_10años['Fecha']=ultimos_10años['Fecha'].map(dt.datetime.toordinal)

# %%
X = ultimos_10años.Fecha.values
X = X.reshape(-1,1)

# %%
Y = ultimos_10años.DolarBlue.values
Y = Y.reshape(-1,1)

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1701, 1)
# (729, 1)
# (1701, 1)
# (729, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(fit_intercept = True)
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
print(lr.rank_)
# Out:
# [[0.05529698]]
# [-40671.12691605]
# 1

# %%
from sklearn.metrics import mean_squared_error
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)
print('Error en datos de train:', mean_squared_error(y_train, y_train_pred))
print('Error en datos de test:', mean_squared_error(y_test, y_test_pred))
# Out:
# Error en datos de train: 1453.791708545562
# Error en datos de test: 1356.8328524454444

# %%
plt.figure(figsize = (10,8))

plt.scatter(X_train, y_train,  color='green', label = 'Datos Train')
plt.plot(X_train, y_train_pred, color='k', linestyle = '--', label = 'Prediccion Train')

plt.scatter(X_test, y_test,  color='red', label = 'Datos Test')
plt.plot(X_test, y_test_pred, color='blue', linewidth=5.0, label = 'Prediccion Test')

plt.legend()
plt.show()

# %%
ultimos_10años.Fecha.max()
# Out:
# 738371

# %% [markdown]
# Le digo que desde la fecha actual que se encuentra en formato ordinal, le agregue 60 para hacer la prediccion en 3 meses y como fecha final 246, que son los dias habiles que cuenta el año

# %%
X_pred = np.arange(ultimos_10años.Fecha.max()+60, ultimos_10años.Fecha.max()+ 246).reshape(-1,1)
X_pred
# Out:
# array([[738431],
#        [738432],
#        [738433],
#        [738434],
#        [738435],
#        [738436],
#        [738437],
#        [738438],
#        [738439],
#        [738440],
#        [738441],
#        [738442],
#        [738443],
#        [738444],
#        [738445],
#        [738446],
#        [738447],
#        [738448],
#        [738449],
#        [738450],
#        [738451],
#        [738452],
#        [738453],
#        [738454],
#        [738455],
#        [738456],
#        [738457],
#        [738458],
#        [738459],
#        [738460],
#        [738461],
#        [738462],
#        [738463],
#        [738464],
#        [738465],
#        [738466],
#        [738467],
#        [738468],
#        [738469],
#        [738470],
#        [738471],
#        [738472],
#        [738473],
#        [738474],
#        [738475],
#        [738476],
#        [738477],
#        [738478],
#        [738479],
#        [738480],
#        [738481],
#        [738482],
# ...

# %%
y_pred = model.predict(X_pred)
y_pred
# Out:
# array([[160.4649372 ],
#        [160.51950319],
#        [160.57406919],
#        [160.62863519],
#        [160.68320118],
#        [160.73776718],
#        [160.79233318],
#        [160.84689918],
#        [160.90146517],
#        [160.95603117],
#        [161.01059717],
#        [161.06516317],
#        [161.11972916],
#        [161.17429516],
#        [161.22886116],
#        [161.28342715],
#        [161.33799315],
#        [161.39255915],
#        [161.44712515],
#        [161.50169114],
#        [161.55625714],
#        [161.61082314],
#        [161.66538914],
#        [161.71995513],
#        [161.77452113],
#        [161.82908713],
#        [161.88365313],
#        [161.93821912],
#        [161.99278512],
#        [162.04735112],
#        [162.10191711],
#        [162.15648311],
#        [162.21104911],
#        [162.26561511],
#        [162.3201811 ],
#        [162.3747471 ],
#        [162.4293131 ],
#        [162.4838791 ],
#        [162.53844509],
#        [162.59301109],
# ...

# %% [markdown]
# Esto me indica que a los 3 meses el dolar blue cotizara $160.46, y al año $170

# %%
X_pred1 = np.arange(ultimos_10años.Fecha.max()+60, ultimos_10años.Fecha.max()+ 123).reshape(-1,1)
X_pred1
# Out:
# array([[738431],
#        [738432],
#        [738433],
#        [738434],
#        [738435],
#        [738436],
#        [738437],
#        [738438],
#        [738439],
#        [738440],
#        [738441],
#        [738442],
#        [738443],
#        [738444],
#        [738445],
#        [738446],
#        [738447],
#        [738448],
#        [738449],
#        [738450],
#        [738451],
#        [738452],
#        [738453],
#        [738454],
#        [738455],
#        [738456],
#        [738457],
#        [738458],
#        [738459],
#        [738460],
#        [738461],
#        [738462],
#        [738463],
#        [738464],
#        [738465],
#        [738466],
#        [738467],
#        [738468],
#        [738469],
#        [738470],
#        [738471],
#        [738472],
#        [738473],
#        [738474],
#        [738475],
#        [738476],
#        [738477],
#        [738478],
#        [738479],
#        [738480],
#        [738481],
#        [738482],
# ...

# %%
y_pred1 = model.predict(X_pred1)
y_pred1
# Out:
# array([[160.4649372 ],
#        [160.51950319],
#        [160.57406919],
#        [160.62863519],
#        [160.68320118],
#        [160.73776718],
#        [160.79233318],
#        [160.84689918],
#        [160.90146517],
#        [160.95603117],
#        [161.01059717],
#        [161.06516317],
#        [161.11972916],
#        [161.17429516],
#        [161.22886116],
#        [161.28342715],
#        [161.33799315],
#        [161.39255915],
#        [161.44712515],
#        [161.50169114],
#        [161.55625714],
#        [161.61082314],
#        [161.66538914],
#        [161.71995513],
#        [161.77452113],
#        [161.82908713],
#        [161.88365313],
#        [161.93821912],
#        [161.99278512],
#        [162.04735112],
#        [162.10191711],
#        [162.15648311],
#        [162.21104911],
#        [162.26561511],
#        [162.3201811 ],
#        [162.3747471 ],
#        [162.4293131 ],
#        [162.4838791 ],
#        [162.53844509],
#        [162.59301109],
# ...

# %% [markdown]
# Esto me indica que a los 6 meses el dolar blue cotizara $163.84
# Como bien sabemos estas predicciones estan mal, puesto que esas brechas ya fueron ampliamente superadas por ello hare otra regresion lineal pero esta vez solo tomando en cuando lo acontecido los ultimos dos años

# %%
ultimos_2años = comparacion.iloc[-488:]
ultimos_2años
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 5076  2020-08-03      136.0         72.52  08  2020
# 5077  2020-08-04      128.0         72.57  08  2020
# 5078  2020-08-05      129.0         72.62  08  2020
# 5079  2020-08-06      130.0         72.70  08  2020
# 5080  2020-08-07      132.0         72.77  08  2020
# ...          ...        ...           ...  ..   ...
# 5562  2022-07-29      296.0        131.23  07  2022
# 5563  2022-08-01      282.0        131.94  08  2022
# 5564  2022-08-02      291.0        132.18  08  2022
# 5565  2022-08-03      298.0        132.41  08  2022
# 5566  2022-08-04      291.0        132.64  08  2022
#
# [488 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)
ultimos_2años['Fecha'] = pd.to_datetime(ultimos_2años['Fecha'], format="%Y/%m/%d")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\1854375854.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_2años['Fecha'] = pd.to_datetime(ultimos_2años['Fecha'], format="%Y/%m/%d")

# %%
import datetime as dt
ultimos_2años['Fecha']=ultimos_2años['Fecha'].map(dt.datetime.toordinal)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\3204981260.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_2años['Fecha']=ultimos_2años['Fecha'].map(dt.datetime.toordinal)

# %%
X1 = ultimos_2años.Fecha.values
X1 = X1.reshape(-1,1)
Y1 = ultimos_2años.DolarBlue.values
Y1 = Y1.reshape(-1,1)

# %%
model.fit(X1,Y1)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, Y1, test_size=0.30, random_state=42)
print(X_train1.shape)
print(X_test1.shape)
print(y_train1.shape)
print(y_test1.shape)
# Out:
# (341, 1)
# (147, 1)
# (341, 1)
# (147, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(fit_intercept = True)
lr.fit(X_train1, y_train1)
print(lr.coef_)
print(lr.intercept_)
print(lr.rank_)
# Out:
# [[0.14732115]]
# [-108542.53331336]
# 1

# %%
from sklearn.metrics import mean_squared_error
y_train_pred1 = lr.predict(X_train1)
y_test_pred1 = lr.predict(X_test1)
print('Error en datos de train:', mean_squared_error(y_train1, y_train_pred1))
print('Error en datos de test:', mean_squared_error(y_test1, y_test_pred1))
plt.figure(figsize = (10,8))

plt.scatter(X_train1, y_train1,  color='green', label = 'Datos Train')
plt.plot(X_train1, y_train_pred1, color='k', linestyle = '--', label = 'Prediccion Train')

plt.scatter(X_test1, y_test1,  color='red', label = 'Datos Test')
plt.plot(X_test1, y_test_pred1, color='blue', linewidth=5.0, label = 'Prediccion Test')

plt.legend()
plt.show()
# Out:
# Error en datos de train: 324.0901207746744
# Error en datos de test: 512.5686395624781

# %% [markdown]
# Como podemos observar en la grafica estos datos tampoco van a ser representativos, por cual procedere a realizar una nueva regresion con el ultimo año

# %%
model = LinearRegression(fit_intercept=True)
ultimo_año['Fecha'] = pd.to_datetime(ultimo_año['Fecha'], format="%Y/%m/%d")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\3174362456.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimo_año['Fecha'] = pd.to_datetime(ultimo_año['Fecha'], format="%Y/%m/%d")

# %%
import datetime as dt
ultimo_año['Fecha']=ultimo_año['Fecha'].map(dt.datetime.toordinal)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\3504892580.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimo_año['Fecha']=ultimo_año['Fecha'].map(dt.datetime.toordinal)

# %%
X2 = ultimo_año.Fecha.values
X2 = X2.reshape(-1,1)
Y2 = ultimo_año.DolarBlue.values
Y2 = Y2.reshape(-1,1)

# %%
model.fit(X2,Y2)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, Y2, test_size=0.30, random_state=42)
print(X_train2.shape)
print(X_test2.shape)
print(y_train2.shape)
print(y_test2.shape)
# Out:
# (172, 1)
# (74, 1)
# (172, 1)
# (74, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(fit_intercept = True)
lr.fit(X_train2, y_train2)
print(lr.coef_)
print(lr.intercept_)
print(lr.rank_)
# Out:
# [[0.19165366]]
# [-141268.12987245]
# 1

# %%
from sklearn.metrics import mean_squared_error
y_train_pred2 = lr.predict(X_train2)
y_test_pred2 = lr.predict(X_test2)
print('Error en datos de train:', mean_squared_error(y_train2, y_train_pred2))
print('Error en datos de test:', mean_squared_error(y_test2, y_test_pred2))
plt.figure(figsize = (10,8))

plt.scatter(X_train2, y_train2,  color='green', label = 'Datos Train')
plt.plot(X_train2, y_train_pred2, color='k', linestyle = '--', label = 'Prediccion Train')

plt.scatter(X_test2, y_test2,  color='red', label = 'Datos Test')
plt.plot(X_test2, y_test_pred2, color='blue', linewidth=5.0, label = 'Prediccion Test')

plt.legend()
plt.show()
# Out:
# Error en datos de train: 378.4163427722567
# Error en datos de test: 697.899654899912

# %% [markdown]
# Considero que los datos aun no son representativos por este motivo voy a realizar una ultima regresion lineal con ultimos 60 dias habiles

# %%
ultimos_60dias = comparacion.iloc[-60:]
ultimos_60dias
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 5507  2022-05-09      201.5        116.76  05  2022
# 5508  2022-05-10      202.0        116.92  05  2022
# 5509  2022-05-11      205.0        117.09  05  2022
# 5510  2022-05-12      203.5        117.25  05  2022
# 5511  2022-05-13      203.5        117.41  05  2022
# 5512  2022-05-16      205.0        117.87  05  2022
# 5513  2022-05-17      208.0        118.04  05  2022
# 5514  2022-05-19      206.0        118.36  05  2022
# 5515  2022-05-20      204.0        118.49  05  2022
# 5516  2022-05-23      206.5        118.95  05  2022
# 5517  2022-05-24      208.0        119.10  05  2022
# 5518  2022-05-26      207.0        119.42  05  2022
# 5519  2022-05-27      206.5        119.56  05  2022
# 5520  2022-05-30      206.5        120.01  05  2022
# 5521  2022-05-31      206.0        120.16  05  2022
# 5522  2022-06-01      206.0        120.33  06  2022
# 5523  2022-06-02      206.0        120.47  06  2022
# ...

# %%
model1 = LinearRegression(fit_intercept=True)
ultimos_60dias['Fecha'] = pd.to_datetime(ultimos_60dias['Fecha'], format="%Y/%m/%d")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\1345523431.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_60dias['Fecha'] = pd.to_datetime(ultimos_60dias['Fecha'], format="%Y/%m/%d")

# %%
import datetime as dt
ultimos_60dias['Fecha']=ultimos_60dias['Fecha'].map(dt.datetime.toordinal)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\2113373831.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_60dias['Fecha']=ultimos_60dias['Fecha'].map(dt.datetime.toordinal)

# %%
X3 = ultimos_60dias.Fecha.values
X3 = X3.reshape(-1,1)
Y3 = ultimos_60dias.DolarBlue.values
Y3 = Y3.reshape(-1,1)

# %%
model1.fit(X3, Y3)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, Y3, test_size=0.30, random_state=42)
print(X_train3.shape)
print(X_test3.shape)
print(y_train3.shape)
print(y_test3.shape)
# Out:
# (42, 1)
# (18, 1)
# (42, 1)
# (18, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(fit_intercept = True)
lr.fit(X_train3, y_train3)
print(lr.coef_)
print(lr.intercept_)
print(lr.rank_)
# Out:
# [[1.48145574]]
# [-1093559.43446671]
# 1

# %%
from sklearn.metrics import mean_squared_error
y_train_pred3 = lr.predict(X_train3)
y_test_pred3 = lr.predict(X_test3)
print('Error en datos de train:', mean_squared_error(y_train3, y_train_pred3))
print('Error en datos de test:', mean_squared_error(y_test3, y_test_pred3))
plt.figure(figsize = (10,8))

plt.scatter(X_train3, y_train3,  color='green', label = 'Datos Train')
plt.plot(X_train3, y_train_pred3, color='k', linestyle = '--', label = 'Prediccion Train')

plt.scatter(X_test3, y_test3,  color='red', label = 'Datos Test')
plt.plot(X_test3, y_test_pred3, color='blue', linewidth=5.0, label = 'Prediccion Test')

plt.legend()
plt.show()
# Out:
# Error en datos de train: 288.2522827391683
# Error en datos de test: 477.94092600712634

# %%
X_pred3 = np.arange(ultimos_60dias.Fecha.max()+60, ultimos_60dias.Fecha.max()+ 123).reshape(-1,1)
X_pred3
# Out:
# array([[738431],
#        [738432],
#        [738433],
#        [738434],
#        [738435],
#        [738436],
#        [738437],
#        [738438],
#        [738439],
#        [738440],
#        [738441],
#        [738442],
#        [738443],
#        [738444],
#        [738445],
#        [738446],
#        [738447],
#        [738448],
#        [738449],
#        [738450],
#        [738451],
#        [738452],
#        [738453],
#        [738454],
#        [738455],
#        [738456],
#        [738457],
#        [738458],
#        [738459],
#        [738460],
#        [738461],
#        [738462],
#        [738463],
#        [738464],
#        [738465],
#        [738466],
#        [738467],
#        [738468],
#        [738469],
#        [738470],
#        [738471],
#        [738472],
#        [738473],
#        [738474],
#        [738475],
#        [738476],
#        [738477],
#        [738478],
#        [738479],
#        [738480],
#        [738481],
#        [738482],
# ...

# %%
y_pred3 = model1.predict(X_pred3)
y_pred3
# Out:
# array([[398.45437064],
#        [399.94791341],
#        [401.44145619],
#        [402.93499896],
#        [404.42854174],
#        [405.92208451],
#        [407.41562729],
#        [408.90917006],
#        [410.40271284],
#        [411.89625561],
#        [413.38979839],
#        [414.88334116],
#        [416.37688394],
#        [417.87042671],
#        [419.36396949],
#        [420.85751226],
#        [422.35105504],
#        [423.84459781],
#        [425.33814059],
#        [426.83168336],
#        [428.32522614],
#        [429.81876891],
#        [431.31231169],
#        [432.80585446],
#        [434.29939724],
#        [435.79294001],
#        [437.28648279],
#        [438.78002556],
#        [440.27356834],
#        [441.76711111],
#        [443.26065389],
#        [444.75419666],
#        [446.24773944],
#        [447.74128221],
#        [449.23482499],
#        [450.72836776],
#        [452.22191054],
#        [453.71545331],
#        [455.20899609],
#        [456.70253887],
# ...

# %%
X_pred4 = np.arange(ultimos_60dias.Fecha.max()+124, ultimos_60dias.Fecha.max()+ 246).reshape(-1,1)
X_pred4
# Out:
# array([[738495],
#        [738496],
#        [738497],
#        [738498],
#        [738499],
#        [738500],
#        [738501],
#        [738502],
#        [738503],
#        [738504],
#        [738505],
#        [738506],
#        [738507],
#        [738508],
#        [738509],
#        [738510],
#        [738511],
#        [738512],
#        [738513],
#        [738514],
#        [738515],
#        [738516],
#        [738517],
#        [738518],
#        [738519],
#        [738520],
#        [738521],
#        [738522],
#        [738523],
#        [738524],
#        [738525],
#        [738526],
#        [738527],
#        [738528],
#        [738529],
#        [738530],
#        [738531],
#        [738532],
#        [738533],
#        [738534],
#        [738535],
#        [738536],
#        [738537],
#        [738538],
#        [738539],
#        [738540],
#        [738541],
#        [738542],
#        [738543],
#        [738544],
#        [738545],
#        [738546],
# ...

# %%
y_pred4 = model1.predict(X_pred4)
y_pred4
# Out:
# array([[494.04110824],
#        [495.53465102],
#        [497.02819379],
#        [498.52173657],
#        [500.01527934],
#        [501.50882212],
#        [503.00236489],
#        [504.49590767],
#        [505.98945044],
#        [507.48299322],
#        [508.97653599],
#        [510.47007877],
#        [511.96362154],
#        [513.45716432],
#        [514.95070709],
#        [516.44424987],
#        [517.93779265],
#        [519.43133542],
#        [520.9248782 ],
#        [522.41842097],
#        [523.91196375],
#        [525.40550652],
#        [526.8990493 ],
#        [528.39259207],
#        [529.88613485],
#        [531.37967762],
#        [532.8732204 ],
#        [534.36676317],
#        [535.86030595],
#        [537.35384872],
#        [538.8473915 ],
#        [540.34093427],
#        [541.83447705],
#        [543.32801982],
#        [544.8215626 ],
#        [546.31510537],
#        [547.80864815],
#        [549.30219092],
#        [550.7957337 ],
#        [552.28927647],
# ...

# %% [markdown]
# Podemos observar como esta prediccion sí se ajusta mejor y es mas representativa a los datos puesto que nos dice que en 3 meses(60 dias habiles) el Blue cotizaria $398,45, en 6 meses $491.05(123 dias habiles) y en 12 meses $674.75(246 dias habiles)

# %% [markdown]
# # # # **Ahora realizare una regresion lineal para poder predecir el dolar oficial

# %%
ultimos_2años = comparacion.iloc[-488:]
ultimos_2años
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 5076  2020-08-03      136.0         72.52  08  2020
# 5077  2020-08-04      128.0         72.57  08  2020
# 5078  2020-08-05      129.0         72.62  08  2020
# 5079  2020-08-06      130.0         72.70  08  2020
# 5080  2020-08-07      132.0         72.77  08  2020
# ...          ...        ...           ...  ..   ...
# 5562  2022-07-29      296.0        131.23  07  2022
# 5563  2022-08-01      282.0        131.94  08  2022
# 5564  2022-08-02      291.0        132.18  08  2022
# 5565  2022-08-03      298.0        132.41  08  2022
# 5566  2022-08-04      291.0        132.64  08  2022
#
# [488 rows x 5 columns]

# %%
model = LinearRegression(fit_intercept=True)
ultimos_2años['Fecha'] = pd.to_datetime(ultimos_2años['Fecha'], format="%Y/%m/%d")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\1854375854.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_2años['Fecha'] = pd.to_datetime(ultimos_2años['Fecha'], format="%Y/%m/%d")

# %%
import datetime as dt
ultimos_2años['Fecha']=ultimos_2años['Fecha'].map(dt.datetime.toordinal)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\3204981260.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_2años['Fecha']=ultimos_2años['Fecha'].map(dt.datetime.toordinal)

# %%
ultimos_2años
# Out:
#        Fecha  DolarBlue  DolarOficial Mes   Año
# 5076  737640      136.0         72.52  08  2020
# 5077  737641      128.0         72.57  08  2020
# 5078  737642      129.0         72.62  08  2020
# 5079  737643      130.0         72.70  08  2020
# 5080  737644      132.0         72.77  08  2020
# ...      ...        ...           ...  ..   ...
# 5562  738365      296.0        131.23  07  2022
# 5563  738368      282.0        131.94  08  2022
# 5564  738369      291.0        132.18  08  2022
# 5565  738370      298.0        132.41  08  2022
# 5566  738371      291.0        132.64  08  2022
#
# [488 rows x 5 columns]

# %%
X4 = ultimos_2años.Fecha.values
X4 = X4.reshape(-1,1)
Y4 = ultimos_2años.DolarOficial.values
Y4= Y4.reshape(-1,1)

# %%
model.fit(X4,Y4)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train4, X_test4, y_train4, y_test4 = train_test_split(X4, Y4, test_size=0.30, random_state=42)
print(X_train4.shape)
print(X_test4.shape)
print(y_train4.shape)
print(y_test4.shape)
# Out:
# (341, 1)
# (147, 1)
# (341, 1)
# (147, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(fit_intercept = True)
lr.fit(X_train4, y_train4)
print(lr.coef_)
print(lr.intercept_)
print(lr.rank_)
# Out:
# [[0.0660327]]
# [-48635.15114735]
# 1

# %%
from sklearn.metrics import mean_squared_error
y_train_pred4 = lr.predict(X_train4)
y_test_pred4 = lr.predict(X_test4)
print('Error en datos de train:', mean_squared_error(y_train4, y_train_pred4))
print('Error en datos de test:', mean_squared_error(y_test4, y_test_pred4))
plt.figure(figsize = (10,8))

plt.scatter(X_train4, y_train4,  color='green', label = 'Datos Train')
plt.plot(X_train4, y_train_pred4, color='k', linestyle = '--', label = 'Prediccion Train')

plt.scatter(X_test4, y_test4,  color='red', label = 'Datos Test')
plt.plot(X_test4, y_test_pred4, color='blue', linewidth=5.0, label = 'Prediccion Test')

plt.legend()
plt.show()
# Out:
# Error en datos de train: 10.122530383038244
# Error en datos de test: 10.048237000560947

# %%
X_pred5 = np.arange(ultimos_2años.Fecha.max()+124, ultimos_2años.Fecha.max()+ 246).reshape(-1,1)
y_pred5 = model.predict(X_pred5)
y_pred5
# Out:
# array([[130.22264049],
#        [130.28961931],
#        [130.35659813],
#        [130.42357695],
#        [130.49055577],
#        [130.55753458],
#        [130.6245134 ],
#        [130.69149222],
#        [130.75847104],
#        [130.82544986],
#        [130.89242867],
#        [130.95940749],
#        [131.02638631],
#        [131.09336513],
#        [131.16034395],
#        [131.22732276],
#        [131.29430158],
#        [131.3612804 ],
#        [131.42825922],
#        [131.49523804],
#        [131.56221685],
#        [131.62919567],
#        [131.69617449],
#        [131.76315331],
#        [131.83013213],
#        [131.89711094],
#        [131.96408976],
#        [132.03106858],
#        [132.0980474 ],
#        [132.16502622],
#        [132.23200503],
#        [132.29898385],
#        [132.36596267],
#        [132.43294149],
#        [132.49992031],
#        [132.56689913],
#        [132.63387794],
#        [132.70085676],
#        [132.76783558],
#        [132.8348144 ],
# ...

# %%
X_pred6 = np.arange(ultimos_2años.Fecha.max()+60, ultimos_2años.Fecha.max()+ 123).reshape(-1,1)
y_pred6 = model.predict(X_pred6)
y_pred6
# Out:
# array([[125.93599614],
#        [126.00297496],
#        [126.06995377],
#        [126.13693259],
#        [126.20391141],
#        [126.27089023],
#        [126.33786905],
#        [126.40484787],
#        [126.47182668],
#        [126.5388055 ],
#        [126.60578432],
#        [126.67276314],
#        [126.73974196],
#        [126.80672077],
#        [126.87369959],
#        [126.94067841],
#        [127.00765723],
#        [127.07463605],
#        [127.14161486],
#        [127.20859368],
#        [127.2755725 ],
#        [127.34255132],
#        [127.40953014],
#        [127.47650895],
#        [127.54348777],
#        [127.61046659],
#        [127.67744541],
#        [127.74442423],
#        [127.81140304],
#        [127.87838186],
#        [127.94536068],
#        [128.0123395 ],
#        [128.07931832],
#        [128.14629713],
#        [128.21327595],
#        [128.28025477],
#        [128.34723359],
#        [128.41421241],
#        [128.48119122],
#        [128.54817004],
# ...

# %% [markdown]
# Se puede observar que se espera que el dolar Oficial dentro los proximos 3 meses llegue a $125.93 y que a los 6 meses el Dolar Oficial cotizaría $130.88, y a los 12 meses lleguaría a $138.32

# %% [markdown]
# # # # # **¿Cual fue el mejor día en los ultimos 4 años para comprar y vender?

# %%
ultimos_4años = comparacion.iloc[-970:]
ultimos_4años
# Out:
#            Fecha  DolarBlue  DolarOficial Mes   Año
# 4591  2018-08-03      28.05         27.38  08  2018
# 4592  2018-08-06      28.10         27.37  08  2018
# 4593  2018-08-07      27.75         27.27  08  2018
# 4594  2018-08-08      27.80         27.52  08  2018
# 4595  2018-08-09      27.95         27.97  08  2018
# ...          ...        ...           ...  ..   ...
# 5562  2022-07-29     296.00        131.23  07  2022
# 5563  2022-08-01     282.00        131.94  08  2022
# 5564  2022-08-02     291.00        132.18  08  2022
# 5565  2022-08-03     298.00        132.41  08  2022
# 5566  2022-08-04     291.00        132.64  08  2022
#
# [970 rows x 5 columns]

# %%
ultimos_4años['pct_change'] =((ultimo_año["DolarBlue"]) / (ultimo_año["DolarBlue"].shift(+1)))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3176\1609240776.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultimos_4años['pct_change'] =((ultimo_año["DolarBlue"]) / (ultimo_año["DolarBlue"].shift(+1)))

# %%
plt.figure(figsize = (20,20))
sns.lineplot(x="Fecha", y="pct_change", data=ultimos_4años)
# Out:
# <AxesSubplot:xlabel='Fecha', ylabel='pct_change'>

# %%
brechamax1= ultimos_4años['pct_change'].idxmax() #para sacar el dia con mayor brecha cambiaria entre la apertura y el cierre de la cotizacion de un mismo dia 

ultimos_4años.loc[brechamax1]
# Out:
# Fecha           2022-07-04
# DolarBlue            260.0
# DolarOficial        125.99
# Mes                     07
# Año                   2022
# pct_change        1.087866
# Name: 5543, dtype: object

# %% [markdown]
# Se puede observar que el dia donde hubo mas brecha entre la apertura y el cierre de jornada fue el día 4/7/2022
